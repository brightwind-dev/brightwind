# %%
import pandas as pd

import sys
module_path = r'C:\BW\RTD\repos-hadley\brightwind\brightwind'
if module_path not in sys.path:
    sys.path.insert(1, module_path)

from analyse import analyse as an
from load.load import load_timeseries
from transform import transform as tf
from plot import plot
from analyse import shear as sh
# path = r'C:\Dropbox (brightwind)\RTD\BrightData\MERA\2018-05-25_MERA-LT-reference-quality\site-data\M352_Calib_Cleaned_20jan2011onwards.csv'
# data = pd.read_csv(path)
# time_col_name = 'TIMESTAMP'
# #yearfirst = False
# #dayfirst = True
# #data[time_col_name] = pd.to_datetime(data[time_col_name],dayfirst=dayfirst,yearfirst=yearfirst)
# std_col_name = 'A_Std1'
# speed_col_name = 'A_Avg1'
# direction_col_name = 'WindDir_AVG'
# sectors = 72
# min_speed = 0.1
# time_interval = 10

import importlib
importlib.reload(an)
importlib.reload(tf)
importlib.reload(plot)
# Out:
# <module 'plot.plot' from 'C:\\BW\\RTD\\repos-hadley\\brightwind\\brightwind\\plot\\plot.py'>

# %%
path = r'C:\Dropbox (brightwind)\RTD\BrightData\MERA\2018-05-25_MERA-LT-reference-quality\site-data\M352_Calib_Cleaned_20jan2011onwards.csv'
data = load_timeseries(path)
data.columns
# Out:
# Index(['A_Avg1', 'A_Std1', 'run1_Max', 'A_Min1', 'A_Avg2', 'A_Std2',
#        'run2_Max', 'A_Min2', 'A__Avg2_2011', 'A__Std2_2011', 'Run__Max2_2011',
#        'A__Min2_2011', 'A_Avg3', 'A_Std3', 'run3_Max', 'A_Min3',
#        'A__Avg3_2011', 'A__Std3_2011', 'Run__Max3_2011', 'A__Min3_2011',
#        'A_Avg4', 'A_Std4', 'run4_Max', 'A_Min4', 'A__Avg4_2011',
#        'A__Std4_2011', 'Run__Max4_2011', 'A__Min4_2011', 'WindDir_AVG',
#        'WindDir_SD', 'Dir1_Max', 'Dir1_Min', 'WindDir_2_AVG', 'WindDir_2_SD',
#        'Dir2_Max', 'Dir2_Min', 'WindDir_3_AVG', 'WindDir_3_SD', 'deg_c_Avg',
#        'Press_mV_Avg'],
#       dtype='object')

# %%
heights=[40, 50, 80]
heights
# Out:
# [40, 50, 80]

# %%
data[['A_Avg1','A_Avg2','A_Avg3']].apply(calc_shear(row, heights))
# Out:
#                      A_Avg1  A_Avg2  A_Avg3
# TIMESTAMP
# 2011-01-20 09:00:00    5.33     NaN     NaN
# 2011-01-20 09:10:00    5.27     NaN     NaN
# 2011-01-20 09:20:00    5.27     NaN     NaN
# 2011-01-20 09:30:00    5.55     NaN     NaN
# 2011-01-20 09:40:00    5.36     NaN     NaN
# 2011-01-20 09:50:00    5.43     NaN     NaN
# 2011-01-20 10:00:00    5.99     NaN     NaN
# 2011-01-20 10:10:00    5.71     NaN     NaN
# 2011-01-20 10:20:00    4.61     NaN     NaN
# 2011-01-20 10:30:00    4.91     NaN     NaN
# 2011-01-20 10:40:00    4.36     NaN     NaN
# 2011-01-20 10:50:00    5.37     NaN     NaN
# 2011-01-20 11:00:00    5.39     NaN     NaN
# 2011-01-20 11:10:00    5.06     NaN     NaN
# 2011-01-20 11:20:00    4.96     NaN     NaN
# 2011-01-20 11:30:00    5.02     NaN     NaN
# 2011-01-20 11:40:00    5.01     NaN     NaN
# 2011-01-20 11:50:00    5.25     NaN     NaN
# 2011-01-20 12:00:00    6.33     NaN     NaN
# 2011-01-20 12:10:00    6.19     NaN     NaN
# ...

# %%
sh.calc_shear(speeds=[data['A_Avg1'], data['A_Avg2'], data['A_Avg3']], heights=[40,60,80])

# %%
an.get_time_continuity_gaps(data)
# Out:
#                  Date From             Date To  Days Lost
# 176345 2014-05-28 23:50:00 2014-05-29 00:10:00   0.013889

# %%
an.get_coverage(data)
# Out:
#                A_Avg1    A_Std1   run1_Max    A_Min1  A_Avg2  A_Std2  \
# TIMESTAMP
# 2011-01-01   6.271714  0.583775   7.690950  4.621404     NaN     NaN
# 2011-02-01   8.261815  0.955546  10.623095  5.649655     NaN     NaN
# 2011-03-01   6.237083  0.708539   7.977881  4.293365     NaN     NaN
# 2011-04-01   7.001463  0.834067   9.022347  4.741586     NaN     NaN
# 2011-05-01  10.643631  1.386837  13.965896  6.817005     NaN     NaN
# 2011-06-01   6.381873  0.746007   8.160345  4.308868     NaN     NaN
# 2011-07-01   5.910354  0.669926   7.496823  4.013311     NaN     NaN
# 2011-08-01   5.820753  0.697491   7.479133  3.911086     NaN     NaN
# 2011-09-01   9.641574  1.218806  12.620093  6.342546     NaN     NaN
# 2011-10-01   8.988519  1.097072  11.687897  5.997095     NaN     NaN
# 2011-11-01   9.722176  1.129296  12.557773  6.654729     NaN     NaN
# 2011-12-01  10.660375  1.341735  14.017503  6.949647     NaN     NaN
# ...

# %%
an.get_basic_stats(data)
# Out:
#                    count        mean        std     min      max
# A_Avg1          231905.0    7.943170   3.618021    0.00    28.27
# A_Std1          231905.0    0.936726   0.569637    0.00     5.49
# run1_Max        231905.0   10.223675   4.833112    0.00    39.33
# A_Min1          231905.0    5.350958   2.424521    0.00    17.96
# A_Avg2               0.0         NaN        NaN     NaN      NaN
# A_Std2               0.0         NaN        NaN     NaN      NaN
# run2_Max             0.0         NaN        NaN     NaN      NaN
# A_Min2               0.0         NaN        NaN     NaN      NaN
# A__Avg2_2011    231905.0    7.890768   3.615861    0.00    28.16
# A__Std2_2011    231905.0    0.938774   0.573355    0.00     5.64
# Run__Max2_2011  231905.0   10.180355   4.844794    0.00    40.04
# A__Min2_2011    231905.0    5.299485   2.425761    0.00    18.02
# A_Avg3               0.0         NaN        NaN     NaN      NaN
# ...

# %%
Instruments = data[[time_col_name,'A_Avg1','A__Avg2_2011','A__Avg3_2011','A__Avg4_2011','WindDir_AVG','WindDir_2_AVG','Press_mV_Avg']]
Tools.get_basic_stats(Instruments,time_col_name)
# Out:
# C:\BW\RTD\repos-hadley\wind-analysis-scripts\analysis_tools\frequency_analysis.py:356: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[time_col_name] = pd.to_datetime(data[time_col_name])
#       Instrument                 mean                  max  \
# 0      TIMESTAMP  2013-04-04 18:00:00  2015-06-19 03:00:00
# 1         A_Avg1              7.94317                28.27
# 2   A__Avg2_2011              7.89077                28.16
# 3   A__Avg3_2011              7.78368                 27.8
# 4   A__Avg4_2011              7.22648                26.43
# 5    WindDir_AVG              208.339                359.9
# 6  WindDir_2_AVG              199.054               359.99
# 7   Press_mV_Avg              982.649              1011.97
#
# ...

# %%
Instruments = data[[time_col_name,'A_Avg1','A__Avg2_2011','A__Avg3_2011','A__Avg4_2011','WindDir_AVG','WindDir_2_AVG','Press_mV_Avg']]
Tools.get_monthly_coverage(Instruments,time_col_name,time_interval)
# Out:
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[time_col_name] = pd.to_datetime(data[time_col_name])
#              A_Avg1  A__Avg2_2011  A__Avg3_2011  A__Avg4_2011  WindDir_AVG  \
# TIMESTAMP
# Jan-2011   0.375000      0.375000      0.375000      0.375000     0.375000
# Feb-2011   1.000000      1.000000      1.000000      1.000000     1.000000
# Mar-2011   1.000000      1.000000      1.000000      1.000000     1.000000
# Apr-2011   1.000000      1.000000      1.000000      1.000000     1.000000
# May-2011   1.000000      1.000000      1.000000      1.000000     1.000000
# Jun-2011   1.000000      1.000000      1.000000      1.000000     1.000000
# ...

# %%
Anemometers = data[[time_col_name,'A_Avg1','A__Avg2_2011','A__Avg3_2011','A__Avg4_2011']]
Tools.get_monthly_means(Anemometers,time_col_name)
# Out:
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[time_col_name] = pd.to_datetime(data[time_col_name])
#               A_Avg1  A__Avg2_2011  A__Avg3_2011  A__Avg4_2011
# TIMESTAMP
# Jan-2011    6.271714      6.243363      6.096894      5.581864
# Feb-2011    8.261815      8.215613      8.084137      7.500037
# Mar-2011    6.237083      6.208882      6.099474      5.670578
# Apr-2011    7.001463      6.961275      6.875000      6.453021
# May-2011   10.643631     10.598109     10.478152      9.792917
# Jun-2011    6.381873      6.350875      6.276069      5.911650
# Jul-2011    5.910354      5.872280      5.852159      5.512841
# ...

# %%
Anemometers = data[[time_col_name,'A_Avg1','A__Avg2_2011','A__Avg3_2011','A__Avg4_2011']]
Tools.plot_monthly_means(Anemometers,time_col_name)
# Out:
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[time_col_name] = pd.to_datetime(data[time_col_name])

# %%
import numpy as np

# %%
an.get_distribution(data['A_Std1'], temp, aggregation_method='count')
# Out:
# variable_bin
# [-0.5, 0.5)       227
# [0.5, 1.5)       2552
# [1.5, 2.5)       7019
# [2.5, 3.5)      12684
# [3.5, 4.5)      17362
# [4.5, 5.5)      22284
# [5.5, 6.5)      25345
# [6.5, 7.5)      26570
# [7.5, 8.5)      25002
# [8.5, 9.5)      22108
# [9.5, 10.5)     18479
# [10.5, 11.5)    15073
# [11.5, 12.5)    11186
# [12.5, 13.5)     8567
# [13.5, 14.5)     5973
# [14.5, 15.5)     4086
# [15.5, 16.5)     2703
# [16.5, 17.5)     1818
# [17.5, 18.5)     1197
# [18.5, 19.5)      670
# [19.5, 20.5)      404
# [20.5, 21.5)      226
# [21.5, 22.5)      175
# [22.5, 23.5)      110
# [23.5, 24.5)       41
# [24.5, 25.5)       25
# [25.5, 26.5)       13
# [26.5, 27.5)        4
# [27.5, 28.5)        2
# [28.5, 29.5)        0
# [29.5, 30.5)        0
# [30.5, 31.5)        0
# [31.5, 32.5)        0
# [32.5, 33.5)        0
# [33.5, 34.5)        0
# [34.5, 35.5)        0
# [35.5, 36.5)        0
# [36.5, 37.5)        0
# [37.5, 38.5)        0
# [38.5, 39.5)        0
# [39.5, 40.5)        0
# ...

# %%
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
temp = pd.read_csv(path,usecols=['TIMESTAMP','A_Avg1'],index_col= 0, parse_dates= True)
temp.shape
# Out:
# (231948, 1)

# %%
analyse.get_distribution

# %%
Tools.plot_TI_by_Speed(data,speed_col_name,std_col_name)
# Out:
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['Turbulence_Intensity'] = data[std_col_name] / data[speed_col_name]

# %%
def get_TI_by_sector(wdspd, wdspd_std, wddir, min_speed=0, sectors=12, direction_bin_array=None, direction_bin_labels=None):
    if isinstance(wdspd, pd.DataFrame) and wdspd.shape[1]==1:
        wdspd = wdspd.iloc[:,0]
    if isinstance(wdspd_std, pd.DataFrame) and wdspd_std.shape[1]==1:
        wdspd_std = wdspd_std.iloc[:,0]
    if isinstance(wddir, pd.DataFrame) and wddir.shape[1]==1:
        wddir = wddir.iloc[:,0]
    ti = pd.concat([wdspd.rename('wdspd'), wdspd_std.rename('wdspd_std'), wddir.rename('wddir')], axis=1, join='inner')
    ti = ti[ti['wdspd']>=min_speed]
    ti['Turbulence_Intensity'] = ti['wdspd_std'] / ti['wdspd']
    ti_dist = pd.concat([an.get_distribution_by_wind_sector(var_series=ti['Turbulence_Intensity'],
                                             direction_series=ti['wddir'],
                                             sectors=sectors, direction_bin_array=direction_bin_array, 
                                             direction_bin_labels=direction_bin_labels,
                                             aggregation_method='mean').rename("Mean_TI"),
                         an.get_distribution_by_wind_sector(var_series=ti['Turbulence_Intensity'],
                                             direction_series=ti['wddir'],
                                             sectors=sectors, direction_bin_array=direction_bin_array, 
                                                            direction_bin_labels=direction_bin_labels,
                                             aggregation_method='count').rename("TI_Count")], axis=1, join='outer')

    ti_dist.index.rename('Direction Bin', inplace=True)
    return ti_dist.dropna(how='all')

# %%
shane_test=pd.read_csv(path)

# %%
cmbnd = pd.concat([an.get_binned_direction_series(data['WindDir_AVG'],sectors=12).rename('Sector'),data['WindDir_AVG']],axis=1,join='inner')
from_us = cmbnd[cmbnd['Sector']==2]

# %%
actual_data = data[(data['WindDir_AVG']>=15.0) & (data['WindDir_AVG']<45.0)].dropna(subset=['A_Avg1','A_Std1','WindDir_AVG'])[['A_Avg1','A_Std1','WindDir_AVG']]

# %%
an.get_TI_by_sector(data['A_Avg1'],data['A_Std1'],data['WindDir_AVG']).index
# Out:
# Index(['345.0-15.0', '15.0-45.0', '45.0-75.0', '75.0-105.0', '105.0-135.0',
#        '135.0-165.0', '165.0-195.0', '195.0-225.0', '225.0-255.0',
#        '255.0-285.0', '285.0-315.0', '315.0-345.0'],
#       dtype='object', name='Direction Bin')

# %%
Tools.plot_TI_by_sector(data,speed_col_name,std_col_name,direction_col_name,sectors,min_speed)
# Out:
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['Turbulence_Intensity'] = data[std_col_name] / data[speed_col_name]

# %%
def get_12x24(var_series,aggregation_method='mean'):
    #Get the 12 month x 24 hour matrix of turbulence intensity
    table_12x24 = pd.concat([var_series.rename('Variable'), var_series.index.to_series().dt.month.rename('Month'),
                             var_series.index.to_series().dt.hour.rename('Hour')], axis=1,join='inner')
    return table_12x24.pivot_table(index='Hour', columns='Month', values='Variable',aggfunc=aggregation_method)

# %%
table_12x24 = an.get_12x24(data['A_Std1']/data['A_Avg1'])

# %%
Tools.get_12x24_TI_matrix(data,time_col_name,speed_col_name,std_col_name)
# Out:
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:589: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['Turbulence_Intensity'] = data.loc[:,std_col_name] / data.loc[:,speed_col_name]
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:590: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[time_col_name] = pd.to_datetime(data[time_col_name])
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:592: SettingWithCopyWarning:
# ...

# %%
plot.plot_12x24_contours(table_12x24, title='Variable')

# %%
Tools.plot_12x24_TI_Contours(data,time_col_name,speed_col_name,std_col_name)
# Out:
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:589: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['Turbulence_Intensity'] = data.loc[:,std_col_name] / data.loc[:,speed_col_name]
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:590: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[time_col_name] = pd.to_datetime(data[time_col_name])
# C:\BW\RTD\repos-Shane\wind-analysis-scripts\analysis_tools\frequency_analysis.py:592: SettingWithCopyWarning:
# ...

# %%
data.columns
# Out:
# Index(['A_Avg1', 'A_Std1', 'run1_Max', 'A_Min1', 'A_Avg2', 'A_Std2',
#        'run2_Max', 'A_Min2', 'A__Avg2_2011', 'A__Std2_2011', 'Run__Max2_2011',
#        'A__Min2_2011', 'A_Avg3', 'A_Std3', 'run3_Max', 'A_Min3',
#        'A__Avg3_2011', 'A__Std3_2011', 'Run__Max3_2011', 'A__Min3_2011',
#        'A_Avg4', 'A_Std4', 'run4_Max', 'A_Min4', 'A__Avg4_2011',
#        'A__Std4_2011', 'Run__Max4_2011', 'A__Min4_2011', 'WindDir_AVG',
#        'WindDir_SD', 'Dir1_Max', 'Dir1_Min', 'WindDir_2_AVG', 'WindDir_2_SD',
#        'Dir2_Max', 'Dir2_Min', 'WindDir_3_AVG', 'WindDir_3_SD', 'deg_c_Avg',
#        'Press_mV_Avg'],
#       dtype='object')

# %%
tab = an.get_freq_table(data['A_Avg1'],data['WindDir_AVG'])

# %%
plot_obj = plot.plot_wind_rose(tab, freq_table=True)
plot_obj

# %%
grad_plot_obj = plot.plot_wind_rose_with_gradient(tab)
grad_plot_obj

# %%
data.columns
# Out:
# Index(['A_Avg1', 'A_Std1', 'run1_Max', 'A_Min1', 'A_Avg2', 'A_Std2',
#        'run2_Max', 'A_Min2', 'A__Avg2_2011', 'A__Std2_2011', 'Run__Max2_2011',
#        'A__Min2_2011', 'A_Avg3', 'A_Std3', 'run3_Max', 'A_Min3',
#        'A__Avg3_2011', 'A__Std3_2011', 'Run__Max3_2011', 'A__Min3_2011',
#        'A_Avg4', 'A_Std4', 'run4_Max', 'A_Min4', 'A__Avg4_2011',
#        'A__Std4_2011', 'Run__Max4_2011', 'A__Min4_2011', 'WindDir_AVG',
#        'WindDir_SD', 'Dir1_Max', 'Dir1_Min', 'WindDir_2_AVG', 'WindDir_2_SD',
#        'Dir2_Max', 'Dir2_Min', 'WindDir_3_AVG', 'WindDir_3_SD', 'deg_c_Avg',
#        'Press_mV_Avg'],
#       dtype='object')

# %%
dist = an.get_distribution(data['A_Std1'],data['A_Avg1'])

# %%
plot = plot.plot_freq_distribution(dist)

# %%
plot
